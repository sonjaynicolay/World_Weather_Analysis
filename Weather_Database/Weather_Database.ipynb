# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=497ad2c6223640dedd64727ac1feeaec

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=497ad2c6223640dedd64727ac1feeaec&q=Boston

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
city_data =[]
#print the beginning of the logging
print("Begining Data Retrieval        ")
print("--------------------------------")
#Create counters
record_count = 1
set_count =1
#Loop through all the cities in our list
for i in range(len(cities)):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50== 0 and i >=50):
        set_count +=1
        record_count =1
    # Create endpoint URL with each city
    city_url =url + "&q=" + "i"
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i >=50):
        set_count +=1
        record_count =1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    # Log the URL, record, and set numbers and the city.
    print(f"processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count +=1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
    # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    #Appnd the city information into city_data list.
        city_data.append({"City": city.title(),
                    "Country": city_country,
                     "Lat": city_lat,
                     "Lng":city_lng,
                     "Max Temp": city_max_temp,
                     "Humidity": city_humidity,
                     "Cloudiness": city_clouds,
                     "Wind Speed":city_wind,
                     "Current Description": city_description})
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    # Indicate that Data loading is complete.
    print("-------------------------------")
    print("Data Retrieval Complete        ")
    print("-------------------------------")
# Out:
# Begining Data Retrieval
# --------------------------------
# processing Record 1 of Set 16 | torbay
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 2 of Set 16 | mataura
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 3 of Set 16 | kapaa
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 4 of Set 16 | aykhal
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 5 of Set 16 | zonguldak
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 6 of Set 16 | nikolskoye
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 7 of Set 16 | la paz
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 8 of Set 16 | bluff
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 9 of Set 16 | tambura
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 10 of Set 16 | punta arenas
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 11 of Set 16 | progreso
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 12 of Set 16 | saskylakh
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 13 of Set 16 | hermanus
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 14 of Set 16 | khasan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 15 of Set 16 | nhulunbuy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 16 of Set 16 | agadez
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 17 of Set 16 | saint george
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 18 of Set 16 | omsukchan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 19 of Set 16 | fortuna
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 20 of Set 16 | portland
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 21 of Set 16 | amderma
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 22 of Set 16 | san policarpo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 23 of Set 16 | northam
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 24 of Set 16 | tiksi
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 25 of Set 16 | albany
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 26 of Set 16 | dikson
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 27 of Set 16 | rocha
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 28 of Set 16 | qaanaaq
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 29 of Set 16 | saint-philippe
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 30 of Set 16 | tuktoyaktuk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 31 of Set 16 | hilo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 32 of Set 16 | labuhan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 33 of Set 16 | castro
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 34 of Set 16 | atuona
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 35 of Set 16 | mehamn
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 36 of Set 16 | puerto ayora
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 37 of Set 16 | carnarvon
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 38 of Set 16 | severo-yeniseyskiy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 39 of Set 16 | bredasdorp
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 40 of Set 16 | palana
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 41 of Set 16 | vaitupu
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 42 of Set 16 | lebu
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 43 of Set 16 | okahandja
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 44 of Set 16 | khatanga
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 45 of Set 16 | waitati
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 46 of Set 16 | utiroa
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 47 of Set 16 | sfantu gheorghe
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 48 of Set 16 | bambous virieux
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 49 of Set 16 | hasaki
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 50 of Set 16 | belushya guba
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 1 of Set 17 | panaba
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 2 of Set 17 | cam ranh
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 3 of Set 17 | santiago del estero
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 4 of Set 17 | geraldton
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 5 of Set 17 | ushuaia
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 6 of Set 17 | barranco
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 7 of Set 17 | buraydah
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 8 of Set 17 | yashan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 9 of Set 17 | batsfjord
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 10 of Set 17 | soyo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 11 of Set 17 | thompson
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 12 of Set 17 | bud
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 13 of Set 17 | new norfolk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 14 of Set 17 | yar-sale
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 15 of Set 17 | bismarck
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 16 of Set 17 | manaure
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 17 of Set 17 | ahipara
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 18 of Set 17 | port elizabeth
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 19 of Set 17 | nanortalik
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 20 of Set 17 | cape town
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 21 of Set 17 | lahij
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 22 of Set 17 | provideniya
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 23 of Set 17 | rikitea
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 24 of Set 17 | kaardi
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 25 of Set 17 | muscat
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 26 of Set 17 | esperance
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 27 of Set 17 | carutapera
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 28 of Set 17 | tiznit
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 29 of Set 17 | jamestown
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 30 of Set 17 | bengkulu
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 31 of Set 17 | busselton
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 32 of Set 17 | yellowknife
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 33 of Set 17 | coquimbo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 34 of Set 17 | mount gambier
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 35 of Set 17 | chokurdakh
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 36 of Set 17 | tsihombe
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 37 of Set 17 | alice
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 38 of Set 17 | mar del plata
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 39 of Set 17 | bilibino
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 40 of Set 17 | avarua
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 41 of Set 17 | tres arroyos
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 42 of Set 17 | dingzhou
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 43 of Set 17 | haibowan
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 44 of Set 17 | vila franca do campo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 45 of Set 17 | halifax
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 46 of Set 17 | gat
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 47 of Set 17 | te anau
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 48 of Set 17 | totolapan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 49 of Set 17 | vaini
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 50 of Set 17 | nichinan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 1 of Set 18 | meulaboh
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 2 of Set 18 | ntcheu
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 3 of Set 18 | nizhneyansk
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 4 of Set 18 | cherskiy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 5 of Set 18 | kosh-agach
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 6 of Set 18 | port alfred
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 7 of Set 18 | hamilton
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 8 of Set 18 | haines junction
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 9 of Set 18 | aflu
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 10 of Set 18 | tuatapere
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 11 of Set 18 | ribeira grande
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 12 of Set 18 | tasiilaq
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 13 of Set 18 | guangyuan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 14 of Set 18 | najran
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 15 of Set 18 | panguna
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 16 of Set 18 | hofn
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 17 of Set 18 | kampene
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 18 of Set 18 | hobart
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 19 of Set
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 2 of Set 22 | zelenoborsk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 3 of Set 22 | nadvoitsy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 4 of Set 22 | hare bay
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 5 of Set 22 | bogande
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 6 of Set 22 | grenville
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 7 of Set 22 | vanavara
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 8 of Set 22 | alofi
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 9 of Set 22 | port hardy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 10 of Set 22 | ayan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 11 of Set 22 | afonso claudio
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 12 of Set 22 | kupang
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 13 of Set 22 | ashqelon
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 14 of Set 22 | eyl
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 15 of Set 22 | rovaniemi
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 16 of Set 22 | srednekolymsk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 17 of Set 22 | sioux lookout
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 18 of Set 22 | los llanos de aridane
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 19 of Set 22 | chabua
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 20 of Set 22 | birjand
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 21 of Set 22 | kavaratti
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 22 of Set 22 | bonfim
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 23 of Set 22 | omuta
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 24 of Set 22 | cabedelo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 25 of Set 22 | bealanana
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 26 of Set 22 | irbeyskoye
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 27 of Set 22 | klaksvik
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 28 of Set 22 | faya
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 29 of Set 22 | grindavik
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 30 of Set 22 | sabang
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 31 of Set 22 | lasa
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 32 of Set 22 | luba
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 33 of Set 22 | raga
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 34 of Set 22 | fort nelson
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 35 of Set 22 | stephenville
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 36 of Set 22 | umm lajj
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 37 of Set 22 | ilulissat
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 38 of Set 22 | karratha
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 39 of Set 22 | san ramon
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 40 of Set 22 | walvis bay
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 41 of Set 22 | oriximina
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 42 of Set 22 | ginir
# -------------------------------
# ...
# Data Retrieval Complete
# -------------------------------
# processing Record 41 of Set 28 | redlands
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 42 of Set 28 | poum
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 43 of Set 28 | san luis
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 44 of Set 28 | aswan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 45 of Set 28 | bulgan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 46 of Set 28 | darhan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 47 of Set 28 | hay river
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 48 of Set 28 | sedelnikovo
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 49 of Set 28 | batagay
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 50 of Set 28 | ishigaki
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 1 of Set 29 | tomatlan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 2 of Set 29 | lazaro cardenas
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 3 of Set 29 | requena
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 4 of Set 29 | muros
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 5 of Set 29 | caravelas
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 6 of Set 29 | almaznyy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 7 of Set 29 | sobolevo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 8 of Set 29 | debre birhan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 9 of Set 29 | teguldet
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 10 of Set 29 | hauterive
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 11 of Set 29 | cap-aux-meules
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 12 of Set 29 | nuoro
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 13 of Set 29 | batemans bay
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 14 of Set 29 | lososina
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 15 of Set 29 | zinder
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 16 of Set 29 | san rafael
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 17 of Set 29 | urengoy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 18 of Set 29 | pong
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 19 of Set 29 | tucuma
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 20 of Set 29 | godec
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 21 of Set 29 | finschhafen
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 22 of Set 29 | kedrovyy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 23 of Set 29 | cap malheureux
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 24 of Set 29 | drayton valley
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 25 of Set 29 | ulaangom
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 26 of Set 29 | andenes
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 27 of Set 29 | tunduru
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 28 of Set 29 | brae
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 29 of Set 29 | ca mau
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 30 of Set 29 | smiltene
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 31 of Set 29 | champaign
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 32 of Set 29 | jasdan
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 33 of Set 29 | babanusah
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 34 of Set 29 | lincoln
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 35 of Set 29 | luau
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 36 of Set 29 | saleilua
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 37 of Set 29 | ukiah
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 38 of Set 29 | miyako
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 39 of Set 29 | karkaralinsk
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 40 of Set 29 | liberal
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 41 of Set 29 | tierranueva
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 42 of Set 29 | vao
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 43 of Set 29 | leningradskiy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 44 of Set 29 | damietta
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 45 of Set 29 | el balyana
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 46 of Set 29 | mbekenyera
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 47 of Set 29 | ratnagiri
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 48 of Set 29 | ruatoria
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 49 of Set 29 | shipunovo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 50 of Set 29 | kapoeta
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 1 of Set 30 | sataua
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 2 of Set 30 | kwakoa
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 3 of Set 30 | polewali
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 4 of Set 30 | gwadar
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 5 of Set 30 | nanded
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 6 of Set 30 | kyren
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 7 of Set 30 | soe
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 8 of Set 30 | sigerfjord
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 9 of Set 30 | clyde
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 10 of Set 30 | papara
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 11 of Set 30 | maun
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 12 of Set 30 | awbari
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 13 of Set 30 | sur
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 14 of Set 30 | heihe
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 15 of Set 30 | ostrovnoy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 16 of Set 30 | rosita
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 17 of Set 30 | lukoyanov
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 18 of Set 30 | teya
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 19 of Set 30 | coihueco
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 20 of Set 30 | padang
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 21 of Set 30 | maku
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 22 of Set 30 | sawakin
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 23 of Set 30 | abu jubayhah
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 24 of Set 30 | evensk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 25 of Set 30 | manjeshwar
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 26 of Set 30 | iralaya
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 27 of Set 30 | harboore
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 28 of Set 30 | nangong
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 29 of Set 30 | lazeshchyna
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 30 of Set 30 | vytegra
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 31 of Set 30 | phalodi
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 32 of Set 30 | arman
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 33 of Set 30 | bom jesus
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 34 of Set 30 | abu dhabi
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 35 of Set 30 | honningsvag
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 36 of Set 30 | maceio
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 37 of Set 30 | mecca
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 38 of Set 30 | baghdad
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 39 of Set 30 | manutuke
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 40 of Set 30 | kununurra
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 41 of Set 30 | mbanza-ngungu
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 42 of Set 30 | flinders
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 43 of Set 30 | severo-zadonsk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 44 of Set 30 | boulder
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 45 of Set 30 | solovetskiy
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 46 of Set 30 | pinsk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 47 of Set 30 | sumenep
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 48 of Set 30 | zmievka
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 49 of Set 30 | atherton
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 50 of Set 30 | kushmurun
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 1 of Set 31 | linshui
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 2 of Set 31 | houston
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 3 of Set 31 | ambunti
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
column_names = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = pd.DataFrame(city_data, columns=column_names)
city_data_df.head()
# Out:
#         City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0     Torbay      CA  47.67  -52.73     48.20        57          20
# 1    Mataura      NZ -46.19  168.86     45.00        73          78
# 2      Kapaa      US  22.08 -159.32     84.20        70           1
# 3     Aykhal      RU  66.00  111.50     14.00        92          20
# 4  Zonguldak      TR  41.25   31.83     61.77        90          39
#
#    Wind Speed Current Description
# 0        5.82          few clouds
# 1       10.00          light rain
# 2       13.87           clear sky
# 3        2.24          few clouds
# 4        4.23    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the Weather_Database into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
